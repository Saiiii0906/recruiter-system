# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# c:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system

# %%
import os

print(
    os.path.exists(
        PROJECT_ROOT / "backend"
    )
)
# Out:
# True

# %%
print(sys.path[-1])
# Out:
# c:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system

# %%
from pathlib import Path
import json

# %%
PROJECT_ROOT = Path.cwd().parent

JD_PATH = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / "jd_features.json"
)

print(JD_PATH.exists())
# Out:
# True

# %%
from backend.jd_processing.jd_parser import (
    load_jd_json
)

print("IMPORT SUCCESS")

print("IMPORT SUCCESS")
# Out:
# IMPORT SUCCESS

# %%
# import traceback

# try:
#     from backend.jd_processing.jd_praser import (
#         load_jd_json
#     )

#     jd_json = load_jd_json(
#         str(JD_PATH)
#     )

#     print(jd_json.keys())

# except Exception:
#     traceback.print_exc()

# %%
jd_json = load_jd_json(str(JD_PATH))

print(jd_json.keys())
# Out:
# dict_keys(['required_skills', 'preferred_skills', 'years_of_experience', 'seniority_level', 'industry', 'domain_expertise', 'behavioral_traits', 'red_flags', 'keywords'])

# %%
from backend.jd_processing.jd_feature import (
    extract_jd_features
)

jd_features = extract_jd_features(
    jd_json
)

jd_features.keys()
# Out:
# dict_keys(['required_skills', 'preferred_skills', 'industry', 'behavioral_traits', 'keywords'])

# %%
len(
    jd_features["required_skills"]
)
# Out:
# 8

# %%
jd_features["required_skills"][:5]
# Out:
# ['Embeddings-based retrieval systems (sentence-transformers, OpenAI embeddings, BGE, E5 or equivalent)',
#  'Vector databases or hybrid search infrastructure (Pinecone, Weaviate, Qdrant, Milvus, OpenSearch, Elasticsearch, FAISS or equivalent)',
#  'Python (production-quality code)',
#  'Evaluation frameworks for ranking systems (NDCG, MRR, MAP, offline-to-online correlation, A/B testing)',
#  'Hybrid retrieval architecture design']

# %%
from backend.scoring.skill_matcher import (
    calculate_skill_match
)

# %%
candidate_skills = [
    "Python",
    "FAISS",
    "LoRA",
    "AWS"
]

score = calculate_skill_match(
    candidate_skills,
    jd_features["required_skills"],
    jd_features["preferred_skills"]
)

print(score)
# Out:
# 25
