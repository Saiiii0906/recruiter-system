# %%
from backend.scoring.report_generator import (
    generate_candidate_report
)

print("IMPORT SUCCESS")
# Out:
# IMPORT SUCCESS

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd

top_candidates = pd.read_csv(
    "../outputs/top_candidates.csv"
)

top_candidates.head()
# Out:
#    candidate_id  semantic_score  experience_years  behavior_score  \
# 0  CAND_0000031           43.00               6.0           59.83
# 1  CAND_0000001           38.99               6.9           51.03
# 2  CAND_0000021           40.01              14.5           13.11
# 3  CAND_0000044           36.58               5.7           15.59
# 4  CAND_0000018           32.84               6.6           34.92
#
#    skill_match_score  final_score  \
# 0                 20        53.47
# 1                  5        47.90
# 2                 30        42.47
# 3                 10        42.13
# 4                  0        41.66
#
#                                          explanation
# 0  Strong semantic alignment with JD | Matched mu...
# 1               Experience falls within target range
# 2  Strong semantic alignment with JD | Matched mu...
# 3               Experience falls within target range
# 4               Experience falls within target range

# %%
print("generate_candidate_report" in globals())
# Out:
# True

# %%
candidate = top_candidates.iloc[0]

report = generate_candidate_report(candidate)

print(report)
# Out:
# Candidate ID: CAND_0000031
#
# Final Score: 53.47
#
# Semantic Score: 43.0
#
# Skill Match Score: 20
#
# Experience Years: 6.0
#
# Why shortlisted:
# Strong semantic alignment with JD | Matched multiple required skills | Experience falls within target range
#
# Recommendation:
# Proceed to recruiter screening.

# %%
# from pathlib import Path

# OUTPUT_DIR = (
#     PROJECT_ROOT
#     / "outputs"
# )

# OUTPUT_DIR.mkdir(
#     exist_ok=True
# )

# top_candidates.to_csv(
#     OUTPUT_DIR / "top_candidates.csv",
#     index=False
# )

# print("Saved Successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       8 OUTPUT_DIR.mkdir(
#       9     exist_ok=True
#      10 )
#      11
# ---> 12 top_candidates.to_csv(
#      13     OUTPUT_DIR / "top_candidates.csv",
#      14     index=False
#      15 )
#
# NameError: name 'top_candidates' is not defined

# %%
# import pandas as pd

# top_candidates = pd.read_csv(
#     "../outputs/top_candidates.csv"
# )

# top_candidates.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2
# ----> 3 top_candidates = pd.read_csv(
#       4     "../outputs/top_candidates.csv"
#       5 )
#       6
#
# File c:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# top_candidates = rank_top_candidates(
#     sample_df,
#     jd_text,
#     jd_features,
#     top_n=10
# )

# top_candidates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 top_candidates = rank_top_candidates(
#       2     sample_df,
#       3     jd_text,
#       4     jd_features,
#
# NameError: name 'rank_top_candidates' is not defined

# %%
# print(type(top_candidates))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(type(top_candidates))
#
# NameError: name 'top_candidates' is not defined
