# %%
import os
import sys

# ensure repo root or parent folder is on sys.path before importing backend
root_path = os.path.abspath(os.getcwd())
sys.path.insert(0, root_path)
sys.path.insert(0, os.path.abspath(os.path.join(root_path, os.pardir)))

from backend.services.data_loader import load_candidates

df = load_candidates()

print(df["candidate_id"].tolist())

df = load_candidates()

print(df["candidate_id"].tolist())
# Out:
# LOADING FILE:
# C:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system\data\raw\india_runs_data_and_ai_challenge\sample_candidates.json
# TOTAL ROWS: 50
# LAST 10 IDS: ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']
# ...

# %%
df = load_candidates()

print(
    sorted(
        df["candidate_id"].tolist()
    )[-10:]
)
# Out:
# LOADING FILE:
# C:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system\data\raw\india_runs_data_and_ai_challenge\sample_candidates.json
# TOTAL ROWS: 50
# LAST 10 IDS: ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']
# ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']

# %%
top_candidates = df[df["candidate_id"].isin(sorted(df["candidate_id"].tolist())[-10:])]

print(top_candidates["candidate_id"].tolist())
# Out:
# ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']

# %%
print(top_candidates["candidate_id"].tolist())
# Out:
# ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']

# %%
from backend.services.data_loader import load_candidates
df = load_candidates()
print(df.columns)
print(df.iloc[30])
print(type(df.iloc[30]))
print(df.iloc[30]["candidate_id"])
# Out:
# LOADING FILE:
# C:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system\data\raw\india_runs_data_and_ai_challenge\sample_candidates.json
# TOTAL ROWS: 50
# LAST 10 IDS: ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']
# Index(['candidate_id', 'profile', 'career_history', 'education', 'skills',
#        'certifications', 'languages', 'redrob_signals'],
#       dtype='str')
# candidate_id                                           CAND_0000031
# profile           {'anonymized_name': 'Ela Singh', 'headline': '...
# career_history    [{'company': 'Swiggy', 'title': 'Recommendatio...
# education         [{'institution': 'SRM University', 'degree': '...
# skills            [{'name': 'Go', 'proficiency': 'intermediate',...
# certifications                                                   []
# languages         [{'language': 'English', 'proficiency': 'nativ...
# ...

# %%
from backend.services.data_loader import load_candidates

df = load_candidates()

value = df.iloc[30]["candidate_id"]

print("Row value :", repr(value))
print("Literal   :", repr("CAND_000031"))

print(value == "CAND_000031")

print(type(value))
print(type("CAND_000031"))

print(value.encode())   
print("CAND_000031".encode())
# Out:
# LOADING FILE:
# C:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system\data\raw\india_runs_data_and_ai_challenge\sample_candidates.json
# TOTAL ROWS: 50
# LAST 10 IDS: ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']
# Row value : 'CAND_0000031'
# Literal   : 'CAND_000031'
# False
# <class 'str'>
# <class 'str'>
# b'CAND_0000031'
# b'CAND_000031'

# %%
print(df.iloc[30])

print()

print(df.iloc[30].to_dict())
# Out:
# candidate_id                                           CAND_0000031
# profile           {'anonymized_name': 'Ela Singh', 'headline': '...
# career_history    [{'company': 'Swiggy', 'title': 'Recommendatio...
# education         [{'institution': 'SRM University', 'degree': '...
# skills            [{'name': 'Go', 'proficiency': 'intermediate',...
# certifications                                                   []
# languages         [{'language': 'English', 'proficiency': 'nativ...
# redrob_signals    {'profile_completeness_score': 83.4, 'signup_d...
# Name: 30, dtype: object
#
# ...

# %%
candidate = df.iloc[30]["candidate_id"]
print(candidate)
print(candidate is value)
# Out:
# CAND_0000031
# False

# %%
from backend.services.data_loader import load_candidates

df = load_candidates()

print(df.iloc[30]["candidate_id"])

print(df.iloc[30]["profile"]["anonymized_name"])
# Out:
# LOADING FILE:
# C:\Users\SRISAIKIRAN\Desktop\sai\projects\recruiter-system\data\raw\india_runs_data_and_ai_challenge\sample_candidates.json
# TOTAL ROWS: 50
# LAST 10 IDS: ['CAND_0000041', 'CAND_0000042', 'CAND_0000043', 'CAND_0000044', 'CAND_0000045', 'CAND_0000046', 'CAND_0000047', 'CAND_0000048', 'CAND_0000049', 'CAND_0000050']
# CAND_0000031
# Ela Singh
